# %%
from dotenv import load_dotenv
load_dotenv()

from custom_gmail_reader import CustomGmailReader

# Instantiate the CustomGmailReader
loader = CustomGmailReader(
    query="",
    max_results=50,
    results_per_page=10,
    service=None
)

# Load the emails
documents = loader.load_data()

# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:20]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: sahildagarwal@gmail.com
# From: Marc Klingen <marc@updates.langfuse.com>
# Subject: Welcome to Langfuse
# Date: Tue, 17 Sep 2024 02:15:56 +0000
# Content snippet:
# Hi Sahil Agarwal,
# Welcome to Langfuse! I'm Marc, one of the founders and here to help in case you have any questions.
#
# Some resources to get you started
#  * Quickstart [https://langfuse.com/docs/get-started] - all the information you need to get set up in one place
#
#  * Detailed integration docs [https://langfuse.com/docs/integrations/overview] (Python&JS SDKs, OpenAI, LangChain, LlamaIndex,
#    API, …)
#
#  * Introduction to tracing [https://langfuse.com/docs/tracing/overview] and its data model in Langfuse
#
#  * Check out the interactive demo [https://langfuse.com/demo] (you have access in your Langfuse account) and play with the chatbot
#    to see your traces in Langfuse
#
#
# If you have ideas regarding the project, share them with the community on Github Discussions [https://langfuse.com/ideas] or just
# reply to this email!
# Also, if you run into issues during setup, reach out to me or create a support thread [https://langfuse.com/gh-support] on GitHub.
#
# Best,
# Marc
#
# P...
# ==================================================
# Document 2:
# To: sahildagarwal@gmail.com
# From: Funcheap <noreply@event.eventbrite.com>
# Subject: Reminder for SF's "COMEDY TAKEOUT" BYO Dinner Stand-Up Comedy Show
# Date: Tue, 17 Sep 2024 02:01:42 +0000
# Content snippet: Eventbrite
#
#
#
#
#
#
#
# Your event is coming up soon!
#             SF's "COMEDY TAKEOUT" BYO Dinner Stand-Up Comedy Show
#
#
#
#
# Wednesday at 7:00 PM
#
#
#
#
# Organized by Funcheap
#
# ------------------------------------------------------------------------
#
#
#
# ----
#
#
#
# ----
#
#
#
# Get your tickets ready
#
#
#
# <tr>
#                 <td >
#
#
#
#
#                 </td>
#                 <td>
#
# More Info: https://itunes.apple.com/us/app/eventbrite-local-events-fun-things-to-do-near-me/id487922291?mt=8&utm_source=eventbrite&utm_medium=attendeeapp&utm_campaign=reminder_email
#
# ------------------------------------------------------------------------
#
#
#
# More Info: https://play.google.com/store/apps/details?id=com.eventbrite.attendee&utm_source=eventbrite&utm_medium=attendeeapp&utm_campaign=reminder_email
#
# ------------------------------------------------------------------------
#
#                 </td>
#       ...
# ==================================================
# Document 3:
# To: sahildagarwal@gmail.com
# From: 950 Tennessee Street <Communications@mc.fsresidential.com>
# Subject: 950 Tennessee - Move-Notice 9.17.24
# Date: Tue, 17 Sep 2024 00:08:07 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 4:
# To: <sahildagarwal@gmail.com>
# From: Experian <support@s.usa.experian.com>
# Subject: Your monthly account statement is here, Sahil
# Date: Mon, 16 Sep 2024 15:30:25 -0600
# Content snippet: Experian:
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.usa.experian.com/u/?qs=2b8edf40cf937f6abbdbf9e718ca01e2a6701e1563ff097acde3dc40c96b3e99316f3066be0e30f18a991cbf186aa692db6d733ee4589e86b8ffc7756ec655e3
#
#
#  Membership ID# 10129500919753297
# https://click.e.usa.experian.com/u/?qs=6ad67911841384b098fef8a063d77e10086fec39834bcc06142a28c5a1ece99ea51a517741a7d5c8e710c1d56acc891b2f63b761f7887e6b8980de755d8986ed
# Sign In
#
#
#
#
#
#
#
#
#
#
#
#  Check out your monthly account statement
#
#
#
#
#
#
#
# 1 unread notifications
# 1 new in the past 30 days
#
# Your credit rating is exceptional
# Next Experian credit report refresh available now
#
#
#  Sign in to see what's new with your credit and make sure you're on the right track.
#
#  Sign in to learn what's impacting your credit so you can take steps to improve it.
#
#
#
#
#
#
#
# https://click.e.usa.experian.com/u/?qs=2b8edf40cf937f6a3d49dbb44f1c501eab802fe995adef21cb57c730108b0fec57a5c63e561a26060003d4d216aacebde3...
# ==================================================
# Document 5:
# To: sahildagarwal@gmail.com
# From: Gradifi Solutions <info@email.gradifi.com>
# Subject: Document submission reminder
# Date: Mon, 16 Sep 2024 20:30:19 +0000
# Content snippet: ...
# ==================================================
# Document 6:
# To: sahildagarwal@gmail.com
# From: Lyft Receipts <no-reply@lyftmail.com>
# Subject: Your ride with Kok Wei on September 16
# Date: Mon, 16 Sep 2024 20:20:37 +0000
# Content snippet: ...
# ==================================================
# Document 7:
# To: <sahildagarwal@gmail.com>
# From: Bank of America <customerservice@emcom.bankofamerica.com>
# Subject: Welcome to your new account, SAHIL
# Date: Mon, 16 Sep 2024 14:04:28 -0600
# Content snippet: ------ Bank of America ------
#
# Want to see the online version of this email from Bank of America?
# Click the link below:
# https://view.emcom.bankofamerica.com/?qs=260cbabeb243acc320e2aec59e7603ec7b9a037a2dae5d206a3b861bb2d62b3b62da45cf85168f0ad0bd4cdc1f9f5f1deadb593a9e9af363c30e48bd34bf4b46218f40617338a93809e3156a6f84165fe7363e800a05e10d
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# You're receiving this servicing email as part of your existing
# relationship with us.
#
# Contact Us:
# https://click.emcom.bankofamerica.com/u/?qs=b1b71abd07cdab8308059e93807943c3e602bda71a082a588c8d333577fbd811067ba0ae76a6d7bc4dbc1433c59362855a628683a7f26b8f
#
# Privacy:
# https://click.emcom.bankofamerica.com/u/?qs=b1b71abd07cdab836185f52e42b51058678d74e1c80360a18e1249250214b5980d61fadb23a6d9c38d6792865c89b881e2a4f0040b157624
#
# Security:
# https://click.emcom.bankofamerica.com/u/?qs=b1b71abd07cdab830f91aa4e0e260239f994...
# ==================================================
# Document 8:
# To: Aditi Jain <aditij89@gmail.com>
# From: "EnTg888@gmail.com" <entg888@gmail.com>
# Subject: Re: FW: Banya &Beats - Special offer for you
# Date: Mon, 16 Sep 2024 12:17:06 -0700
# Content snippet: I think its not at Banya SF, it’s at a new sauna space called Alchemy, less
# naked Russians
#
# On Mon, Sep 16, 2024 at 11:25 AM Aditi Jain <aditij89@gmail.com> wrote:
#
# > But also kind of intriguing at the same time haha
# >
# > On Mon, Sep 16, 2024 at 11:20 AM Aditi Jain <aditij89@gmail.com> wrote:
# >
# >> Definitely interesting idea…but Banya is high effort for me already
# >> (based on one visit though) so DJ would be too much stimulation personally
# >> 😂
# >>
# >> On Mon, Sep 16, 2024 at 11:05 AM Jenny Kwan <jennylkwan@gmail.com> wrote:
# >>
# >>> Haha is the DJ music calming? Seems like a funny pairing bc banya is
# >>> super relaxing
# >>>
# >>> On Mon, Sep 16, 2024 at 11:00 AM EnTg888@gmail.com <entg888@gmail.com>
# >>> wrote:
# >>>
# >>>> Sauna and DJ 👀
# >>>>
# >>>> ---------- Forwarded message ---------
# >>>> From: 이진영 <smiling36@naver.com>
# >>>> Date: Mon, Sep 16, 2024 at 10:47 AM
# >>>> Subject: FW: Banya &Beats - Special offer for you
# >>>> To: <entg888@gmail.com>
# >>>>
# >>>>
# >>>>
# ...>
# ==================================================
# Document 9:
# To: <sahildagarwal@gmail.com>
# From: Delta Dental <no-reply@dd.delta.org>
# Subject: Is it time for a cleaning?
# Date: Mon, 16 Sep 2024 15:10:02 -0400
# Content snippet: Is it time for a cleaning, Sahil?
#
# Has it been six months since your last cleaning? Schedule a cleaning and polish up that smile. After all, a pearly white grin will never go out of style.
#
# If you need to find a dentist or just want to try someone new, check out our  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c3 Find a Dentist  tool.
#
#
#  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c4 Find a dentist
#
#
# Was this information helpful?
#
#  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c5 Yes 	  	  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c6 No
#
#
# Thanks,
# Delta Dental of California
#
#  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c7 	 http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c8 	 http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47c9 	 http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47ca 	 http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47cb
#
#
#  http://t.dd.delta.org/r/?id=tae60b69,579f1b99,56ec47cc&e=cDE9...
# ==================================================
# Document 10:
# To: Jenny Kwan <jennylkwan@gmail.com>
# From: Aditi Jain <aditij89@gmail.com>
# Subject: Re: FW: Banya &Beats - Special offer for you
# Date: Mon, 16 Sep 2024 11:24:59 -0700
# Content snippet: But also kind of intriguing at the same time haha
#
# On Mon, Sep 16, 2024 at 11:20 AM Aditi Jain <aditij89@gmail.com> wrote:
#
# > Definitely interesting idea…but Banya is high effort for me already (based
# > on one visit though) so DJ would be too much stimulation personally 😂
# >
# > On Mon, Sep 16, 2024 at 11:05 AM Jenny Kwan <jennylkwan@gmail.com> wrote:
# >
# >> Haha is the DJ music calming? Seems like a funny pairing bc banya is
# >> super relaxing
# >>
# >> On Mon, Sep 16, 2024 at 11:00 AM EnTg888@gmail.com <entg888@gmail.com>
# >> wrote:
# >>
# >>> Sauna and DJ 👀
# >>>
# >>> ---------- Forwarded message ---------
# >>> From: 이진영 <smiling36@naver.com>
# >>> Date: Mon, Sep 16, 2024 at 10:47 AM
# >>> Subject: FW: Banya &Beats - Special offer for you
# >>> To: <entg888@gmail.com>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>> -----Original Message-----
# >>> *From*: "Alchemy Team"<team@alchemysprings.com>
# >>> *To*: <smiling36@naver.com>
# >>> *Cc*:
# >>> *Sent*: 2024. 9. 16 AM 7:31:40
# >>> *Subject*: Banya & Beats - ...
# ==================================================
# Document 11:
# To: Jenny Kwan <jennylkwan@gmail.com>
# From: Aditi Jain <aditij89@gmail.com>
# Subject: Re: FW: Banya &Beats - Special offer for you
# Date: Mon, 16 Sep 2024 11:20:43 -0700
# Content snippet: Definitely interesting idea…but Banya is high effort for me already (based
# on one visit though) so DJ would be too much stimulation personally 😂
#
# On Mon, Sep 16, 2024 at 11:05 AM Jenny Kwan <jennylkwan@gmail.com> wrote:
#
# > Haha is the DJ music calming? Seems like a funny pairing bc banya is super
# > relaxing
# >
# > On Mon, Sep 16, 2024 at 11:00 AM EnTg888@gmail.com <entg888@gmail.com>
# > wrote:
# >
# >> Sauna and DJ 👀
# >>
# >> ---------- Forwarded message ---------
# >> From: 이진영 <smiling36@naver.com>
# >> Date: Mon, Sep 16, 2024 at 10:47 AM
# >> Subject: FW: Banya &Beats - Special offer for you
# >> To: <entg888@gmail.com>
# >>
# >>
# >>
# >>
# >>
# >> -----Original Message-----
# >> *From*: "Alchemy Team"<team@alchemysprings.com>
# >> *To*: <smiling36@naver.com>
# >> *Cc*:
# >> *Sent*: 2024. 9. 16 AM 7:31:40
# >> *Subject*: Banya & Beats - Special offer for you
# >>
# >> Tickets going fast  - Banya & Beats this Sunday
# >>
# >> Tickets Going Fast!
# >>
# >>
# >>
# >> Join us for
# >>
# >> Banya & Beats Day ...
# ==================================================
# Document 12:
# To: "EnTg888@gmail.com" <entg888@gmail.com>
# From: Jenny Kwan <jennylkwan@gmail.com>
# Subject: Re: FW: Banya &Beats - Special offer for you
# Date: Mon, 16 Sep 2024 11:05:03 -0700
# Content snippet: Haha is the DJ music calming? Seems like a funny pairing bc banya is super
# relaxing
#
# On Mon, Sep 16, 2024 at 11:00 AM EnTg888@gmail.com <entg888@gmail.com>
# wrote:
#
# > Sauna and DJ 👀
# >
# > ---------- Forwarded message ---------
# > From: 이진영 <smiling36@naver.com>
# > Date: Mon, Sep 16, 2024 at 10:47 AM
# > Subject: FW: Banya &Beats - Special offer for you
# > To: <entg888@gmail.com>
# >
# >
# >
# >
# >
# > -----Original Message-----
# > *From*: "Alchemy Team"<team@alchemysprings.com>
# > *To*: <smiling36@naver.com>
# > *Cc*:
# > *Sent*: 2024. 9. 16 AM 7:31:40
# > *Subject*: Banya & Beats - Special offer for you
# >
# > Tickets going fast  - Banya & Beats this Sunday
# >
# > Tickets Going Fast!
# >
# >
# >
# > Join us for
# >
# > Banya & Beats Day Party
# >
# > *Sunday September 22nd, 11am-9pm*
# >
# >
# >
# > We're crazy excited to sweat, plunge, dance and connect with our community
# > this weekend. Our first ever wellness day party is jam packed with some of
# > our favorite DJs, artists, teachers, makers and mo...
# ==================================================
# Document 13:
# To: sahildagarwal@gmail.com
# From: "Ben (The Feed)" <hello@thefeed.com>
# Subject: 💸 Hi Sahil, you have $15.00 store credit to spend at The Feed.
# Date: Mon, 16 Sep 2024 18:03:48 +0000 (UTC)
# Content snippet: Hi Sahil,
#
# A quick reminder that you have credit that is getting lonely and
# wants to be spent at The Feed.
#
#
#
# Your current Store Credit Balance is:
# $15.00
#
# Don't wait too long, you only have 30 days before your credit
# disappears 👻
#
# Using store credit is as easy as 1,2,3!
#
# * Go to The Feed ( https://t.dripemail2.com/c/eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkZXRvdXIiLCJpc3MiOiJtb25vbGl0aCIsInN1YiI6ImRldG91cl9saW5rIiwiaWF0IjoxNzI2NTA5ODI5LCJuYmYiOjE3MjY1MDk4MjksImFjY291bnRfaWQiOiI0OTY2NzQ4IiwiZGVsaXZlcnlfaWQiOiIwN2d0Mng2YTN6cGEzeGJxNmR2YSIsInVybCI6Imh0dHBzOi8vdGhlZmVlZC5jb20_X19zPTYzbm42bXUweTRrbDRleDdwdGo4In0.vkqUpTjg9DAUBKgyiqbr3HiKd_r3E6bprFxemPY0ju8 )
# * Make sure you are logged in to your account
# * During checkout, you will see a checkbox to apply your store
# credit to your order.
#
# That's it! If you need any help, just hit reply and I can help
# apply store credit to your order for you.
#
# Ben
#
# Coach
#
# The Feed.
#
# ---------------------
# To make sure you keep getting th...
# ==================================================
# Document 14:
# To: Sahil Agarwal <sahildagarwal@gmail.com>, Jenny Kwan <jennylkwan@gmail.com>, Aditi Jain <aditij89@gmail.com>, Sreya Sengupta <sreya.sengupta@gmail.com>
# From: "EnTg888@gmail.com" <entg888@gmail.com>
# Subject: Fwd: FW: Banya &Beats - Special offer for you
# Date: Mon, 16 Sep 2024 11:00:22 -0700
# Content snippet: Sauna and DJ 👀
#
# ---------- Forwarded message ---------
# From: 이진영 <smiling36@naver.com>
# Date: Mon, Sep 16, 2024 at 10:47 AM
# Subject: FW: Banya &Beats - Special offer for you
# To: <entg888@gmail.com>
#
#
#
#
#
# -----Original Message-----
# *From*: "Alchemy Team"<team@alchemysprings.com>
# *To*: <smiling36@naver.com>
# *Cc*:
# *Sent*: 2024. 9. 16 AM 7:31:40
# *Subject*: Banya & Beats - Special offer for you
#
# Tickets going fast  - Banya & Beats this Sunday
#
# Tickets Going Fast!
#
#
#
# Join us for
#
# Banya & Beats Day Party
#
# *Sunday September 22nd, 11am-9pm*
#
#
#
# We're crazy excited to sweat, plunge, dance and connect with our community
# this weekend. Our first ever wellness day party is jam packed with some of
# our favorite DJs, artists, teachers, makers and more.
#
#
#
# If you haven't purchased your ticket yet, don't wait! Early Bird tickets
# sold out in 48 hours and main sale is going fast.
#
# **** ANNOUNCING DJ Set Times ****
#
# *2-3pm *
# * EXOENDO**3-4pm *
# *Golden Ratio**4-5pm ...
# ==================================================
# Document 15:
# To: sahildagarwal@gmail.com
# From: Redfin <listings@redfin.com>
# Subject: 1514 Clair Mel Circle Home Report — 49 nearby homes listed recently
# Date: Mon, 16 Sep 2024 17:00:25 +0000
# Content snippet: Redfin  ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
# ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏
#
#
#
#  <https://www.redfin.com/>
#
#
#  September 2024 Home Report
#
#
#
#
#  Your Home Estimate
# 1514 Clair Mel Circle
# <https://www.redfin.com/myredfin/home-dashboard/property/47161699#redfin-estimate>
#
#
#  $188,261
#
#
# +$98K since sold
#
#
#  View estimate details
# <https://www.redfin.com/myredfin/home-dashboard/property/47161699#redfin-estimate>
#
#
#
#  Estimated sale price
#
#
#
#
# <https://www.redfin.com/sell-a-home/seller-consultation?inquirySource=388&propertyId=47161699>
#
#  $179K–$213K
#
#  Thinking about selling? Get a local Redfin agent's opinion on your home's
# value and the state of the Tampa market.
#
#
#
#
#  Request a free analysis
# <https://www.redfin.com/sell-a-home/seller-consultation?inquirySource=388&propertyId=47161699>
#
#
#
#
#
#  Recently listed 33619
#
#
#
#
#
#  49
#
#  New listings
#
#
#  $249
#
#  Median $/sq. ft.
#
#
#  9,537...
# ==================================================
# Document 16:
# To: Irene Shih <irene@mindsmatterbay.org>
# From: Irene Shih <irene@mindsmatterbay.org>
# Subject: Please Read: 9/16 School Night Progress Update
# Date: Mon, 16 Sep 2024 08:00:00 -0700
# Content snippet: Dear MMBay Volunteers, Boards, and Advisors,
#
# Thank you all for your energy and persistence, as we continue our historic
# sponsorship run for October 8 (Tuesday)'s School Night Event
# <http://www.schoolnightmindsmatterbay.org>! We are *3 weeks away* from the
# event. Here's our latest weekly progress update:
#
#    - Goals: *$800K* revenue target
#       - Sell 20 tables (8 seats each), each table is $40K
#       - Sell 40 individual (non-sponsor) tickets at $350 each
#       - Yield $50K *net* in auction item sales
#    - Results to date: *$636,355* raised
#       - *~ 15.5 tables* sponsored
#          - Permira: *$250K* Growth Investor sponsor level (6 and 1/4 tables
#          or 50 seats) - thank you to our Board member *Alex Vander-Linde* and
#          AB members *Jenna Neher*, *Conor Holohan*, *James **Maycher*,
# and *Candice
#          Li* for championing us!
#          - Davis Polk: *$65K* Impact Advocate sponsor level (1 and 1/2
#          tables or 12 seats) - thank you to our Board me...
# ==================================================
# Document 17:
# To: "sahildagarwal@gmail.com" <sahildagarwal@gmail.com>
# From: Wealthfront Client Services <support@wealthfront.com>
# Subject: My Personal Investment Account | Funds invested
# Date: Mon, 16 Sep 2024 14:06:35 +0000 (UTC)
# Content snippet: Wealthfront, Inc.
#
# Your investment is complete
#
# Your funds have been invested in My Personal Investment Account. For a more detailed view of how your funds have been allocated, check your Investment Account page.
#
# See Investment Account: https://email.wealthfront.com/ls/click?upn=u001.s3OayoLTE-2FSi7MbfilrqC1Wb4QOncRuvWHPHQ8wkclHIkwxATMrDXX-2FGfG7qzkQXdnTwi06nzgVoVn4dY8q0EYopLC0KEBmEovqTmUy-2BUl9QUuYooBRc4Hi1-2B3mfoRR7c90S_VbmpvM0lca6f-2Ffte3462aJ0IUYTU1-2BtrHONUypS5RTZPkjf52T83pGQPKdQBY8jI6LLx70Uzc0sYtraztNyi9cRomBll-2FdK6gbWgfnDorQFsSNpkULLxaUJdw57WvOFJDs4CLvQBYK95-2FyBzwSzP3NI7d4xxNzE5wgOytC-2FIwH3-2BvV6UaO6d1c9ayUB-2FQq9V6Qt7RsFe8TufN4P-2BbLtIhKyVn6kDPHkslPPkrXiusNkf4z5pEhrAuIHdJOk-2B17gjqnauZv8C2fZtx8heui7JTk5CKw-2BijaaQgxtYe9kTwfu34LDSF2TvzXYnSQ0ojEBNSAG-2B3QQa1idic7iWHELoTg-3D-3D
#
#
# - The Wealthfront Team
#
#
# Questions? Visit our Help Center at https://email.wealthfront.com/ls/click?upn=u001.s3OayoLTE-2FSi7MbfilrqC1Wb4QOncRuvWHPHQ8wkclHFp7rday5WCw2J5Tv9uQbtJ4nsD6kMoMPGW...
# ==================================================
# Document 18:
# To: sahil agarwal <sahildagarwal@gmail.com>
# From: GitHub <noreply@github.com>
# Subject: [GitHub] A third-party GitHub Application has been added to your account
# Date: Mon, 16 Sep 2024 03:27:13 +0000 (UTC)
# Content snippet: Hey sahilda!
#
# A third-party GitHub Application (Render) with the following permissions:
#
#   - View your email addresses
#
# Was recently authorized to access your account.
#
# Visit https://github.com/settings/connections/applications/Iv1.558507eb9b186639 for more information.
#
# To see this and other security events for your account, visit https://github.com/settings/security-log
#
# If you run into problems, please contact support by visiting https://github.com/contact
#
# Thanks,
# The GitHub Team
#
# ...
# ==================================================
# Document 19:
# To: sahildagarwal@gmail.com
# From: Alaska Airlines <service@ifly.alaskaair.com>
# Subject: Your confirmation receipt: NZSSTH for your flight on 10/3/24.
# Date: Mon, 16 Sep 2024 03:00:19 +0000
# Content snippet: Alaska Airlines®
#  https://ifly.alaskaair.com/pub/cc?_ri_=X0Gzc2X%3DAQjkPkSUYQGf8BIWSai2Nt8kewzcX85N2zcPzbzaUdHtCnWze5G306LYzga9yvzacGyYfaRbVXtpKX%3DTYUWCCCCY&_ei_=EZePAFeY7DwwDXYI-zmd94bIfPsm3GCM460wzHi3W_E2GpccHJ6BpKSTTCaFn9zduIOaD_0nMefTItxl8E726x_s9JDX76hHd1_GIwYMuPYQF1e39wARS0JICf5ih4NfvYCdjXBZ4pcP5v3r65cSjr2mfn03mkTLAJh-igM-lTH4lQPEwqAbdHNYFg.&_di_=qe1alv774obol4to6624fanousl8fd26a40oervvetp7ld9aej00Jg%3D%3D
#
# Manage your trip with us ->
#  https://ifly.alaskaair.com/pub/cc?_ri_=X0Gzc2X%3DAQjkPkSUYQGf8BIWSai2Nt8kewzcX85N2zcPzbzaUdHtCnWze5G306LYzga9yvzacGyYfaRbVXtpKX%3DTYUWCCDRY&_ei_=EZePAFeY7DwwDXYI-zmd94bIfPsm3GCM460wzHi3W_E2GpccHJ6BpKSTTCaFn9zduIOaD_0nMefTItxl8E726x-UtevwkodJ7yioQglCGy0obVgpudXBce7l6MSqtCubJE3RB4A5O1WpbhmgEAQTNdlSLLTwvkwaUNMjkNVqEx4QH0FTvdA0X066CI9LaNotOxScsV9ErOU6c_4S08jZoQ9iycEsa94.&_di_=7bhq30k6ha5m6kth6vj0st44gkdt8gfh9g84kb8osk2bbc1ebnd0Jg%3D%3D
#
# ======================================================================
#
# Special travel instructions apply ...
# ==================================================
# Document 20:
# To: SahilDAgarwal@gmail.com
# From: "Akash Patel (via Google Photos)" <noreply-bac1cc8d1cf560d3415cb623930c81b9@google.com>
# Subject: Akash Patel shared “SD Tri 2024” with you
# Date: Sun, 15 Sep 2024 19:52:09 -0700
# Content snippet: Google Photos
#
# Akash Patel shared an album with you:
# https://photos.google.com/share/AF1QipO_WkQ1Fxr3ajg1YmUxA39qUFnd1OkSARiQE7tgZmFn6W22g85mUqCWs1b0vPWjHw?key=VHk5TnU4cnc1WEJETnNFa3o1TnlnbGNSQW5RVTZn&obfsgid=113738796895125024141&email=sahildagarwal@gmail.com
#
# View photos here:
# https://photos.google.com/share/AF1QipO_WkQ1Fxr3ajg1YmUxA39qUFnd1OkSARiQE7tgZmFn6W22g85mUqCWs1b0vPWjHw?key=VHk5TnU4cnc1WEJETnNFa3o1TnlnbGNSQW5RVTZn&obfsgid=113738796895125024141&email=sahildagarwal@gmail.com
#
# You received this mail because Akash Patel shared these photos with you. If
# you no longer wish to receive email notifications of shared photos,
# unsubscribe here:
# https://myaccount.google.com/communication-preferences/unsubscribe?ct=AIbu_FsBAd7lcQKMkqTCDniqwbjGVF2U3gobFu5g8mIdRzx409JiORAMpeQ4Iy90cIhV8xpzXlWFWKaUMZ1fF8pXALwmN4kvsfgGFZKzaiLOT2YcRskuQYtWVH9NLnT4972ZMIeTzQoyh5AHJ4k6xggGRIQ4_gd5Sr-2cyUsA6_NMLb6RiYeyBWPmT4Du20i3Zj1XiawZ1cI36CEimxw0y2j5A&utm_source=ch&utm_medium=email&auto=tru...
# ==================================================

# %%
from llama_index.core import Settings
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler

langfuse_callback_handler = LlamaIndexCallbackHandler(
  public_key="pk-lf-341d3363-36a0-44a6-ae57-b70d1ab254c3",
  secret_key="sk-lf-ac395939-c5cc-4379-97f9-dbf670d8cd64",
  host="https://cloud.langfuse.com"
)
Settings.callback_manager = CallbackManager([langfuse_callback_handler])

from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
response = query_engine.query("What's the most private thing there?")
print(response)
# Out:
# The most private thing mentioned in the context is the address "2407 Harrison St, #13, San Francisco, CA 94110, USA" provided in one of the emails.
